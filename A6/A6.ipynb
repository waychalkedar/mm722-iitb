# %% [markdown]
# A6 involves simulating a liquid and using the radial distribution function (RDF) to calculate "the average number of atoms in the first shell for any reference atom". We use the `compute rdf` command in our input script so LAMMPS evaluates the RDF for us. The systems vary in the LJ cutoff provided; the potential cuts off (i.e. is set to zero) after $r = n\sigma$ for $n = 2, 2.5, 3, 3.5, 4, 4.5, 5$. <br>
# **Please run the input script to generate the appropriate dump files to test out the code yourself.** You can run the simulation for only two cutoffs to visualize how changing the cutoff changes the RDF.
# The `A6_submission.pdf` files goes through the theory and contextualizes the plots.

# %%
run rdf_r.py

# %% [markdown]
# This generates plots for each cutoff value which look similar to: <br>
# ![A6_cut=3.5_tstep=110000.png](attachment:2e5d8b9e-7f87-4cc6-bf45-dffdf48d2f3e.png)

# %%
run rdf_r_time.py

# %% [markdown]
# This generates plots like the following for the 0, 30000th, 60000th, 90000th, 110000th timestep: <br>
# ![image.png](attachment:267ca00c-cac2-45b8-bcde-8f407d94aa5a.png)

# %%
run area_all.py

# %% [markdown]
# This generates plots for each cutoff value which look like: <br>
# ![A6_calc_cut=3.5_tstep=14980000.png](attachment:2a431965-e98e-4ad2-9557-813f3d8260ca.png)
#
# The area is evaluated between the green shaded region.
