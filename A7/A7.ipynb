# %% [markdown]
# A7 involves visualizing how the radius of gyration for a polymer of different length varies with simulation time. Biophysics predict that such polymers 'collapse' over time to reduce their size (which is quantified through various properties like radius of gyration, end-to-end distance, solvent-accessible surface area).

# %%
run all_ensembles.py

# %% [markdown]
# These generate plots like:
# ![A7_plots_40.png](attachment:978bb511-77b8-4944-9bb1-5c7629eef15d.png)
# For an example of the longer simulation,
# ![A7_longplots_100.png](attachment:7771ff9f-49dd-4a0d-a419-d389b362bcfd.png)

# %% [markdown]
# ### Ensemble average ###
# We are tasked to find the ensemble average of radius of gyration $\left\langle{R_g}\right\rangle$ for the 20-length polymer. This is done by taking the mean of $R_g$ across ensembles at $t = 5\tau$ where $\tau$ = time constant, as estimated by the `tau` function in the script.

# %%
run 20_ensavg.py

# %% [markdown]
# This generates the following output:
# ![image.png](attachment:297f07c1-b605-43ab-b608-c45237e0c9ac.png)

# %% [markdown]
# ### Time average ##
# We are tasked to find the time average of radius of gyration $\bar{R_g}$ for the 20-length polymer. This is done by taking the mean of $R_g$ for one ensemble across the span $t = [\tau, t_{final}]$ where $\tau$ = time constant as before

# %%
run 20_tavg.py

# %% [markdown]
# This generates the output:
# ![image.png](attachment:24ff3b6a-2e6f-440a-be9e-ea28c45bb14b.png)

# %% [markdown]
# ### Time- and ensemble-averages for all systems ###
# We now compare the time and ensemble averages across all systems.

# %%
run all_avg.py

# %% [markdown]
# This gives the plot:
# ![Q4_A7.png](attachment:45600a92-c46a-4881-8be6-062c15a8a3af.png)

# %% [markdown]
# ## Radius of gyration vs polymer length ##
# As the assignment statement says,
# $$ \left\langle{R_g^2}\right\rangle = \dfrac{1}{6}Nb^2 \text{ i.e. } \left\langle{R_g}\right\rangle \propto N^{1/2}$$
# This implies that, if we plot $\left\langle{R_g}\right\rangle \text{ vs } N$ on log-log axes, we should see a straight line with slope = 0.5

# %%
run Rg_N.py

# %% [markdown]
# This gives the output plot as:
# ![Q5_A7.png](attachment:190864d2-66f5-4582-b870-5ceddf788ef1.png)
