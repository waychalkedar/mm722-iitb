# %% [markdown]
# A2 is about seeing the variation in number of particles on one side of the simulation box. <br>
# ```dump_4.file``` (attached in repository) looks like:
# ![Screenshot 2024-04-06 172929.png](attachment:4170c7e0-564a-4e89-97d2-011b4d3d1c08.png)
# This loops over the number of timesteps (you can see that data is dumped every 100 timesteps).

# %%
run A2_1.py
